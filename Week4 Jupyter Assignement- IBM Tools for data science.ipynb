# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# __ERIA SOLOMON KATUMBA__<br>
# Data Scientist

# %% [markdown]
# <h4><i>I am interested in data science because of how it's techqinues can help companies grow revenue and profit for example in marketing analytics, customer segmentation, evaluation of marketing campaigns etc </i></h4>

# %% [markdown]
# <h3>Code in cell 5 below will produce the product of variable a and b </h3>

# %%
a=2
b=4
a*b
# Out:
# 8

# %% [markdown]
# this content above the horizontal rule
# ***
# this is content below the horizontal rule
#
# below is a numbered list of my favorite libraries
#
# 1. pandas
#     + data manipulation
#     + transformation
# 2. seaborn
#     + visualisation
#     + providing sample datasets
# 3. matplotlib
#     + graph visualizations
# 4. scikitlearn
#     + model development
# 5. prophet
#     + forecasting time series
# 6. folium
#     + map visualization
#
#  <h2>An External Link</h2>
# <a href="https://www.coursera.org/learn/open-source-tools-for-data-science/ungradedLti/Z1VP1/peer-graded-assignment" target="_blank" rel="noopener noreferrer">link text</a>
#
# <h2>An image</h2>
#
# ![library-book-shelves-book-box-vector-13375469.jpg](attachment:5ae827bb-47d6-49ec-ab2f-3c47ed1c9209.jpg)
